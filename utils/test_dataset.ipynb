# %%
import json

def load_json_file(filepath):
    with open(filepath, 'r') as file:
        data = json.load(file)
    return data

filepath="/mnt/petrelfs/songmingyang/songmingyang/data/mm/annotation/LLaVA-Human-Preference-10K/llava_7b_v1_preference.json"
data = load_json_file(filepath)
ans_file = open(filepath, "r",encoding="utf8")
for line in ans_file:
    print(line)
    break
# Out:
# [

# %%
data[0]
# Out:
# dict_keys(['id', 'image', 'conversations', 'output_1', 'output_2', 'preference', 'hallucination', 'flip', 'length_bias'])

# %%
data[0]['conversations'][-2]
# Out:
# {'from': 'human',
#  'value': 'Can you give possible reasons for the crowd of people to be walking in the street?'}

# %%
data[0][f"output_{data[0]['preference']}"]
# Out:
# {'from': 'llava',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 图片路径
img_path = "/mnt/petrelfs/songmingyang/songmingyang/data/mm/imgs/train2017/000000245946.jpg"

# 读取并显示图片
img = mpimg.imread(img_path)
plt.imshow(img)
plt.show()
